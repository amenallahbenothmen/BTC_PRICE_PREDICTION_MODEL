# %%
import pandas as pd 
import yfinance as yf 
from datetime import datetime

# %%
now = datetime.now()
end_date = now.strftime('%Y-%m-%d')

# %%
interest_rates = yf.download("^IRX", start='2014-09-17', end=end_date)
df3 = pd.DataFrame({
    'DateTime': interest_rates.index,
    'INT_Rate': interest_rates['Close']
})
df3.drop(columns='DateTime',inplace=True)
expected_dates = pd.date_range(start='2014-09-17', end=end_date, freq='D')
df3 = df3.reindex(expected_dates)
df3['INT_Rate'] = df3['INT_Rate'].fillna(method='ffill')
df3 = df3.iloc[:-1]
# Out:
# [*********************100%%**********************]  1 of 1 completed
# C:\Users\amenm\AppData\Local\Temp\ipykernel_2520\1302010652.py:9: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df3['INT_Rate'] = df3['INT_Rate'].fillna(method='ffill')

# %%
df3
# Out:
#             INT_Rate
# 2014-09-17     0.013
# 2014-09-18     0.010
# 2014-09-19     0.007
# 2014-09-20     0.007
# 2014-09-21     0.007
# ...              ...
# 2024-05-01     5.250
# 2024-05-02     5.238
# 2024-05-03     5.238
# 2024-05-04     5.238
# 2024-05-05     5.238
#
# [3519 rows x 1 columns]

# %%
expected_dates = pd.date_range(start='2014-09-17', end=end_date, freq='D')
df3 = df3.reindex(expected_dates)
df3['INT_Rate'] = df3['INT_Rate'].fillna(method='ffill')
df3 = df3.iloc[:-1]
# Out:
# C:\Users\amenm\AppData\Local\Temp\ipykernel_11436\3862097775.py:3: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df3['INT_Rate'] = df3['INT_Rate'].fillna(method='ffill')

# %%
df3
# Out:
#             INT_Rate
# 2014-09-17     0.013
# 2014-09-18     0.010
# 2014-09-19     0.007
# 2014-09-20     0.007
# 2014-09-21     0.007
# ...              ...
# 2024-05-01     5.250
# 2024-05-02     5.238
# 2024-05-03     5.235
# 2024-05-04     5.235
# 2024-05-05     5.235
#
# [3519 rows x 1 columns]

# %%
symbol = "^GSPC"
start_date = '2014-09-17'
now = datetime.now()
end_date = now.strftime('%Y-%m-%d')
stock_indices = yf.download(symbol, start=start_date, end=end_date)
df_1 = pd.DataFrame({
                'DateTime': stock_indices.index,
                'open_stk': stock_indices['Open'],
                'high_stk': stock_indices['High'],
                'low_stk': stock_indices['Low'],
                'close_stk': stock_indices['Close'],
                'volume_stk': stock_indices['Volume']
            })

compare_date = pd.to_datetime("2014-10-01")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
df_1.head(25)
# Out:
#              DateTime     open_stk     high_stk      low_stk    close_stk  \
# Date
# 2014-09-17 2014-09-17  1999.300049  2010.739990  1993.290039  2001.569946
# 2014-09-18 2014-09-18  2003.069946  2012.339966  2003.069946  2011.359985
# 2014-09-19 2014-09-19  2012.739990  2019.260010  2006.589966  2010.400024
# 2014-09-22 2014-09-22  2009.079956  2009.079956  1991.010010  1994.290039
# 2014-09-23 2014-09-23  1992.780029  1995.410034  1982.770020  1982.770020
# 2014-09-24 2014-09-24  1983.339966  1999.790039  1978.630005  1998.300049
# 2014-09-25 2014-09-25  1997.319946  1997.319946  1965.989990  1965.989990
# 2014-09-26 2014-09-26  1966.219971  1986.369995  1966.219971  1982.849976
# 2411 2024-05-01  5029.029785  5096.120117  5013.450195  5018.390137
# 2412 2024-05-02  5049.319824  5073.209961  5011.049805  5064.200195
# 2413 2024-05-03  5122.779785  5139.120117  5101.220215  5127.790039
#
#       volume_stk
# 0     4188590000
# 1     4012510000
# 2     3560970000
# 3     3358220000
# 4     3687870000
# ...          ...
# 2409  3447450000
# 2410  4082470000
# 2411  4544170000
# 2412  4381660000
# 2413  2441285000
#
# [2414 rows x 6 columns]

# %%
inflation_data = yf.download('TIP', start=start_date, end=end_date)
df5=pd.DataFrame({
    'inflation': inflation_data['Close'] 
})
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
df5
# Out:
#              inflation
# Date
# 2014-09-17  112.000000
# 2014-09-18  111.709999
# 2014-09-19  112.040001
# 2014-09-22  111.959999
# 2014-09-23  112.379997
# ...                ...
# 2024-04-29  106.040001
# 2024-04-30  105.529999
# 2024-05-01  105.010002
# 2024-05-02  105.389999
# 2024-05-03  105.930000
#
# [2424 rows x 1 columns]

# %%
symbol = "^GSPC"
start_date = '2014-09-17'
now = datetime.now()
end_date = now.strftime('%Y-%m-%d')
stock_indices = yf.download(symbol, start=start_date, end=end_date)
df = pd.DataFrame({
                'DateTime': interest_rates.index,
                'open_stk': stock_indices['Open'],
                'high_stk': stock_indices['High'],
                'low_stk': stock_indices['Low'],
                'close_stk': stock_indices['Close'],
                'volume_stk': stock_indices['Volume']
            })


            #df['open_stk'] = df['open_stk'].fillna(method='ffill')
            #df['high_stk'] = df['high_stk'].fillna(method='ffill')
            #df['low_stk'] = df['low_stk'].fillna(method='ffill')
            #df['close_stk'] = df['close_stk'].fillna(method='ffill')
            #df['volume_stk'] = df['volume_stk'].fillna(method='ffill')
            #compare_date = pd.to_datetime("2014-10-01")
            #df["DateTime"] = pd.to_datetime(df.index)
            #df = df[df["DateTime"] >= compare_date]
            #df.drop(columns='DateTime', inplace=True)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 6
#       4 end_date = now.strftime('%Y-%m-%d')
#       5 stock_indices = yf.download(symbol, start=start_date, end=end_date)
# ----> 6 df = pd.DataFrame({
#       7                 'DateTime': interest_rates.index,
#       8                 'open_stk': stock_indices['Open'],
#       9                 'high_stk': stock_indices['High'],
#      10                 'low_stk': stock_indices['Low'],
#      11                 'close_stk': stock_indices['Close'],
#      12                 'volume_stk': stock_indices['Volume']
#      13             })
#      15             #expected_dates = pd.date_range(start='2014-09-17', end=end_date, freq='D')
#      16             #df = df.reindex(expected_dates)
#      17             #df['open_stk'] = df['open_stk'].fillna(method='ffill')
#    (...)
#      24             #df = df[df["DateTime"] >= compare_date]
#      25             #df.drop(columns='DateTime', inplace=True)
#
# File c:\Users\amenm\miniconda3\envs\lstmenv\lib\site-packages\pandas\core\frame.py:778, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     772     mgr = self._init_mgr(
#     773         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     774     )
#     776 elif isinstance(data, dict):
#     777     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 778     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     779 elif isinstance(data, ma.MaskedArray):
#     780     from numpy.ma import mrecords
#
# File c:\Users\amenm\miniconda3\envs\lstmenv\lib\site-packages\pandas\core\internals\construction.py:503, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     499     else:
#     500         # dtype check to exclude e.g. range objects, scalars
#     501         arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
# --> 503 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File c:\Users\amenm\miniconda3\envs\lstmenv\lib\site-packages\pandas\core\internals\construction.py:114, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     111 if verify_integrity:
#     112     # figure out the index, if necessary
#     113     if index is None:
# --> 114         index = _extract_index(arrays)
#     115     else:
#     116         index = ensure_index(index)
#
# File c:\Users\amenm\miniconda3\envs\lstmenv\lib\site-packages\pandas\core\internals\construction.py:690, in _extract_index(data)
#     685     if lengths[0] != len(index):
#     686         msg = (
#     687             f"array length {lengths[0]} does not match index "
#     688             f"length {len(index)}"
#     689         )
# --> 690         raise ValueError(msg)
#     691 else:
#     692     index = default_index(lengths[0])
#
# ValueError: array length 2422 does not match index length 2424

# %%
expected_dates = pd.date_range(start='2014-09-17', end=end_date, freq='D')

# %%
expected_dates
# Out:
# DatetimeIndex(['2014-09-17', '2014-09-18', '2014-09-19', '2014-09-20',
#                '2014-09-21', '2014-09-22', '2014-09-23', '2014-09-24',
#                '2014-09-25', '2014-09-26',
#                ...
#                '2024-04-27', '2024-04-28', '2024-04-29', '2024-04-30',
#                '2024-05-01', '2024-05-02', '2024-05-03', '2024-05-04',
#                '2024-05-05', '2024-05-06'],
#               dtype='datetime64[ns]', length=3520, freq='D')

# %%
symbol = "^GSPC"
start_date = '2014-09-17'
now = datetime.now()
end_date = now.strftime('%Y-%m-%d')
stock_indices = yf.download(symbol, start=start_date, end=end_date)
df3= pd.DataFrame({
                'DateTime': stock_indices.index,
                'open_stk': stock_indices['Open'],
                'high_stk': stock_indices['High'],
                'low_stk': stock_indices['Low'],
                'close_stk': stock_indices['Close'],
                'volume_stk': stock_indices['Volume']
            })
expected_dates = pd.date_range(start='2014-09-17', end=end_date, freq='D')
df3 = df3.reindex(expected_dates)
df3 = df3.iloc[:-1]  
df3['open_stk'] = df3['open_stk'].fillna(method='ffill')
df3['high_stk'] = df3['high_stk'].fillna(method='ffill')
df3['low_stk'] = df3['low_stk'].fillna(method='ffill')
df3['close_stk'] = df3['close_stk'].fillna(method='ffill')
df3['volume_stk'] = df3['volume_stk'].fillna(method='ffill')
compare_date = pd.to_datetime("2014-10-01")
df3["DateTime"] = pd.to_datetime(df3.index)
df3 = df3[df3["DateTime"] >= compare_date]
df3.drop(columns='DateTime', inplace=True)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# C:\Users\amenm\AppData\Local\Temp\ipykernel_2520\1609160807.py:17: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df3['open_stk'] = df3['open_stk'].fillna(method='ffill')
# C:\Users\amenm\AppData\Local\Temp\ipykernel_2520\1609160807.py:18: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df3['high_stk'] = df3['high_stk'].fillna(method='ffill')
# C:\Users\amenm\AppData\Local\Temp\ipykernel_2520\1609160807.py:19: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df3['low_stk'] = df3['low_stk'].fillna(method='ffill')
# C:\Users\amenm\AppData\Local\Temp\ipykernel_2520\1609160807.py:20: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df3['close_stk'] = df3['close_stk'].fillna(method='ffill')
# C:\Users\amenm\AppData\Local\Temp\ipykernel_2520\1609160807.py:21: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df3['volume_stk'] = df3['volume_stk'].fillna(method='ffill')

# %%
df3
# Out:
#                open_stk     high_stk      low_stk    close_stk    volume_stk
# 2014-10-01  1971.439941  1971.439941  1941.719971  1946.160034  4.188590e+09
# 2014-10-02  1945.829956  1952.319946  1926.030029  1946.170044  4.012510e+09
# 2014-10-03  1948.119995  1971.189941  1948.119995  1967.900024  3.560970e+09
# 2014-10-04  1948.119995  1971.189941  1948.119995  1967.900024  3.560970e+09
# 2014-10-05  1948.119995  1971.189941  1948.119995  1967.900024  3.560970e+09
# ...                 ...          ...          ...          ...           ...
# 2024-05-01  5029.029785  5096.120117  5013.450195  5018.390137  4.544170e+09
# 2024-05-02  5049.319824  5073.209961  5011.049805  5064.200195  4.381660e+09
# 2024-05-03  5122.779785  5139.120117  5101.220215  5127.790039  2.441285e+09
# 2024-05-04  5122.779785  5139.120117  5101.220215  5127.790039  2.441285e+09
# 2024-05-05  5122.779785  5139.120117  5101.220215  5127.790039  2.441285e+09
#
# [3505 rows x 5 columns]
